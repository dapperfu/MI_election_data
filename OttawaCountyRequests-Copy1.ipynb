# %%
import requests

# %%
s = requests.Session()
s.headers.update({'referer': "https://elections.miottawa.org/ElectionResults/Election/Summary/NOV0618"})

# %%
r = s.post("https://elections.miottawa.org/ElectionResults/Election/Export")

# %%
r = requests.get("https://elections.miottawa.org/ElectionResults/Election/Export", 
      headers={'Referer': "https://elections.miottawa.org/ElectionResults/Election/Summary/NOV0618"})

# %%
r.b
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta name="Description" content="County of Ottawa Michigan Election Results" />\r\n    <meta lang="en-us" />\r\n    <meta name="keywords" content="Election, Ottawa, County, Proposal, Millage, Clerks, Primary" />\r\n    <meta name="author" content="Ottawa County IT" />\r\n    <title>Ottawa County Election Results</title>\r\n    \r\n    <!-- Load miOttawa.org stylesheets for header -->\r\n\r\n    <link rel="stylesheet" type="text/css" href="/electionresults/Content/main.css">\r\n    <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/layout.css">\r\n    <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/top-navigation.css">\r\n    <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/left-navigation.css">\r\n    <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/styles.css">\r\n    <link re
# ...

# %%
import IPython.display

# %%
IPython.display.HTML(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="Description" content="County of Ottawa Michigan Election Results" />
#     <meta lang="en-us" />
#     <meta name="keywords" content="Election, Ottawa, County, Proposal, Millage, Clerks, Primary" />
#     <meta name="author" content="Ottawa County IT" />
#     <title>Ottawa County Election Results</title>
#
#     <!-- Load miOttawa.org stylesheets for header -->
#
#     <link rel="stylesheet" type="text/css" href="/electionresults/Content/main.css">
#     <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/layout.css">
#     <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/top-navigation.css">
#     <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/left-navigation.css">
#     <link rel="stylesheet" type="text/css" href="/electionresults/Content/miottawa_css/styles.css">
# ...
